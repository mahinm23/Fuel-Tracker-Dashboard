# %%
import pandas as pd
import matplotlib.pyplot as plt

fuel = pd.read_csv('Trips.csv')
fuel.head()
# Out:
#      Location   MPG   Mileage  Miles      Cost  Estimated TFL Travel Date  \
# 0     Romford  35.3  100053.0    6.2  1.083658           3.50  01/05/2026
# 1     Romford  31.3  100042.0    8.3  1.636097           3.50  01/05/2026
# 2     7 kings  31.0  100036.0    2.6  0.517472           1.75  01/05/2026
# 3   Goodmayes  36.6  100033.0    8.5  1.432891           3.50  01/05/2026
# 4  Gidea park  37.1  100025.0   10.5  1.746187           5.50  01/05/2026
#
#                                                 Tank
# 0  99714 (https://www.notion.so/99714-31f37dd2ebd...
# 1  99714 (https://www.notion.so/99714-31f37dd2ebd...
# 2  99714 (https://www.notion.so/99714-31f37dd2ebd...
# 3  99714 (https://www.notion.so/99714-31f37dd2ebd...
# 4  99714 (https://www.notion.so/99714-31f37dd2ebd...

# %%
fuel['Cost'] = fuel['Cost'].round(2)
print(fuel['Cost'])
# Out:
# 0       1.08
# 1       1.64
# 2       0.52
# 3       1.43
# 4       1.75
#        ...
# 369    10.06
# 370    19.38
# 371      NaN
# 372      NaN
# 373      NaN
# Name: Cost, Length: 374, dtype: float64

# %%
fuel['Mileage'] = fuel['Mileage'].astype('Int64')
print(fuel['Mileage'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/Documents/Projects/Fuel-Tracker-Dashboard/venv/lib/python3.14/site-packages/pandas/core/arrays/integer.py:63, in IntegerDtype._safe_cast(cls, values, dtype, copy)
#      62 try:
# ---> 63     return values.astype(dtype, casting="safe", copy=copy)
#      64 except TypeError as err:
#
# TypeError: Cannot cast array data from dtype('float64') to dtype('int64') according to the rule 'safe'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 fuel['Mileage'] = fuel['Mileage'].astype('Int64')
#       2 print(fuel['Mileage'])
#
# File ~/Documents/Projects/Fuel-Tracker-Dashboard/venv/lib/python3.14/site-packages/pandas/core/generic.py:6541, in NDFrame.astype(self, dtype, copy, errors)
# ...
